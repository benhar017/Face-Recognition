# %%
import numpy
import cv2
import matplotlib.pyplot as plt

# %%
#path=r"C:\Users\Lenovo\Documents\HCI\face"
img=cv2.imread('face.jpg')
print(img)
# Out:
# [[[239 235 230]
#   [239 235 230]
#   [238 234 229]
#   ...
#   [232 230 229]
#   [233 231 230]
#   [233 231 230]]
#
#  [[239 235 230]
#   [238 234 229]
#   [238 234 229]
#   ...
#   [232 230 229]
#   [233 231 230]
#   [233 231 230]]
#
#  [[239 235 230]
#   [238 234 229]
#   [238 234 229]
#   ...
#   [232 230 229]
#   [233 231 230]
#   [233 231 230]]
#
#  ...
#
#  [[218 215 207]
#   [218 215 207]
#   [218 215 207]
#   ...
#   [213 219 242]
#   [223 225 236]
#   [224 227 232]]
#
#  [[219 214 205]
#   [220 215 206]
#   [221 216 207]
#   ...
#   [189 199 253]
#   [186 197 224]
#   [214 223 236]]
#
#  [[219 214 205]
#   [220 215 206]
#   [221 216 207]
#   ...
#   [147 159 231]
#   [181 196 229]
#   [208 223 239]]]

# %%
img.shape
# Out:
# (930, 698, 3)

# %%
img2=cv2.resize(img,(400,400))#resize
img.shape
# Out:
# (930, 698, 3)

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
cv2.imshow("my windpw",img)
cv2.waitKey(0)
cv2.destroyALLWindows()

# %%
face_xml=r""
face_cascade=cv2.CascadeClassifier(face_xml)
faces=face_cascade.detectMultiScale(img)
faces
